# %% [markdown]
# # **Descargar archivo ICFES completo 🔽📖📊**

# %%
import gdown

# Enlace directo de Google Drive
file_id = "1aoTOIjZa4eMfyExbbPdDo7bczDMjwY-n"
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Descargar el archivo a la carpeta local
output = "results_icfes_total.csv"
gdown.download(download_url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1aoTOIjZa4eMfyExbbPdDo7bczDMjwY-n
# From (redirected): https://drive.google.com/uc?export=download&id=1aoTOIjZa4eMfyExbbPdDo7bczDMjwY-n&confirm=t&uuid=5be0a9a3-f0aa-4a3a-92dc-aa840dc2caac
# To: /content/results_icfes_total.csv
# 100%|██████████| 2.99G/2.99G [00:14<00:00, 204MB/s]
# 'results_icfes_total.csv'

# %% [markdown]
# # **Descargar archivo hogares completo 🔽📖🏠**

# %%
import gdown

# Enlace directo de Google Drive
file_id = "1wgO49F3TkMJBWEbMQJltBH4e05yVSxMB"
download_url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Descargar el archivo a la carpeta local
output = "hogares_total_limpios_descargado.csv"
gdown.download(download_url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1wgO49F3TkMJBWEbMQJltBH4e05yVSxMB
# From (redirected): https://drive.google.com/uc?export=download&id=1wgO49F3TkMJBWEbMQJltBH4e05yVSxMB&confirm=t&uuid=eba1d149-5de8-4a81-be17-f888eb438453
# To: /content/hogares_total_limpios_descargado.csv
# 100%|██████████| 106M/106M [00:01<00:00, 96.2MB/s]
# 'hogares_total_limpios_descargado.csv'

# %% [markdown]
# # Dataframe Icfes (5 primeras filas) 🐼

# %%
import pandas as pd
icfes = pd.read_csv('results_icfes_total.csv', delimiter=';', nrows=5)
icfes.head()
# Out:
#    PERIODO ESTU_TIPODOCUMENTO  ESTU_CONSECUTIVO COLE_AREA_UBICACION  \
# 0    20131                 CR  SB11201310000414              URBANO
# 1    20194                 TI  SB11201940464873               RURAL
# 2    20194                 TI  SB11201940464873               RURAL
# 3    20122                 TI  SB11201220204399              URBANO
# 4    20132                 TI  SB11201320464198              URBANO
#
#   COLE_BILINGUE COLE_CALENDARIO      COLE_CARACTER  \
# 0             N               B          ACADÉMICO
# 1             N               A  TÉCNICO/ACADÉMICO
# 2             N               A  TÉCNICO/ACADÉMICO
# 3             N               A  TÉCNICO/ACADÉMICO
# 4             N               A            TÉCNICO
#
#    COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 0                   311848000812        311848000812
# 1                   141016000305        241016000342
# 2                   141016000305        241016000342
# 3                   163130000718        163130000718
# 4                   119001000559        119001000559
#
#    COLE_COD_DEPTO_UBICACION  ...  FAMI_TIENECOMPUTADOR  FAMI_TIENEINTERNET  \
# 0                        11  ...                    Si                  Si
# 1                        41  ...                    Si                  Si
# 2                        41  ...                    Si                  Si
# 3                        63  ...                    Si                  Si
# 4                        19  ...                    Si                  Si
#
#   FAMI_TIENELAVADORA DESEMP_INGLES PUNT_INGLES PUNT_MATEMATICAS  \
# 0                 Si            B+          94               88
# 1                 Si            B1          71               66
# 2                 Si            B1          71               66
# 3                 No            A1          48               45
# 4                 Si            A-          43               52
#
#   PUNT_SOCIALES_CIUDADANAS PUNT_C_NATURALES PUNT_LECTURA_CRITICA PUNT_GLOBAL
# 0                      NaN              NaN                  NaN         NaN
# 1                     70.0             65.0                 69.0       339.0
# 2                     70.0             65.0                 69.0       339.0
# 3                      NaN              NaN                  NaN         NaN
# 4                      NaN              NaN                  NaN         NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# # Dataframe Hogares 🐼

# %%
hogares = pd.read_csv('hogares_total_limpios_descargado.csv', low_memory=False)
hogares
# Out:
#         PERIODO  DIRECTORIO  SECUENCIA_ENCUESTA  SECUENCIA_P  P5010  P8526  \
# 0        2020.0   7247300.0                 1.0          1.0    2.0    1.0
# 1        2020.0   7247301.0                 1.0          1.0    1.0    1.0
# 2        2020.0   7247302.0                 1.0          1.0    3.0    1.0
# 3        2020.0   7247303.0                 1.0          1.0    2.0    1.0
# 4        2020.0   7247304.0                 1.0          1.0    2.0    1.0
# ...         ...         ...                 ...          ...    ...    ...
# 585051   2023.0   8201918.0                 1.0          1.0    2.0    1.0
# 585052   2023.0   8201924.0                 1.0          1.0    1.0    2.0
# 585053   2023.0   8201925.0                 1.0          1.0    1.0    1.0
# 585054   2023.0   8201926.0                 1.0          1.0    1.0    2.0
# 585055   2023.0   8201927.0                 1.0          1.0    1.0    2.0
#
#         P8530       fex_c  REGION  DEPARTAMENTO  ...  PISOS  PAREDES  \
# 0         1.0  513.690889     1.0           8.0  ...    NaN      NaN
# 1         1.0  482.968201     1.0           8.0  ...    NaN      NaN
# 2         1.0  488.435003     1.0           8.0  ...    NaN      NaN
# 3         1.0  537.650079     1.0           8.0  ...    NaN      NaN
# 4         1.0  438.176737     1.0           8.0  ...    NaN      NaN
# ...       ...         ...     ...           ...  ...    ...      ...
# 585051    1.0         NaN     3.0          66.0  ...    NaN      NaN
# 585052    2.0         NaN     9.0          91.0  ...    NaN      NaN
# 585053    1.0         NaN     3.0          66.0  ...    NaN      NaN
# 585054    1.0         NaN     3.0          66.0  ...    NaN      NaN
# 585055    1.0         NaN     3.0          66.0  ...    NaN      NaN
#
#         HACINAMIENTO   IPM  POBRE  P1075  P1077S21  P1077S22  P1077S23  \
# 0                NaN   NaN    NaN    NaN       NaN       NaN       NaN
# 1                NaN   NaN    NaN    NaN       NaN       NaN       NaN
# 2                NaN   NaN    NaN    NaN       NaN       NaN       NaN
# 3                NaN   NaN    NaN    NaN       NaN       NaN       NaN
# 4                NaN   NaN    NaN    NaN       NaN       NaN       NaN
# ...              ...   ...    ...    ...       ...       ...       ...
# 585051           NaN  0.10    0.0    2.0       2.0       2.0       2.0
# 585052           NaN  0.10    0.0    2.0       2.0       2.0       2.0
# 585053           NaN  0.15    0.0    2.0       2.0       2.0       2.0
# 585054           NaN  0.10    0.0    2.0       2.0       2.0       2.0
# 585055           NaN  0.10    0.0    1.0       2.0       2.0       2.0
#
#               FEXP
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 585051  217.072372
# 585052   17.516954
# 585053  145.993759
# 585054   30.973490
# 585055   80.246124
#
# [585056 rows x 63 columns]

# %% [markdown]
# # **Consultando PERIODOS en Icfes y en Hogares📖📊**

# %%
###  https://github.com/factordeveloper/Modelo_Completo_K-means_/blob/main/Consultando_Periodos.ipynb

# %% [markdown]
# # K means

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Cargar los archivos CSV
hogares = pd.read_csv('hogares_total_limpios_descargado.csv')
icfes = pd.read_csv('results_icfes_total.csv', delimiter=';')

# Seleccionar las columnas de interés de cada dataset
hogares_selected = hogares[['personas', 'empleo_formal', 'desempleo_larga_duracion', 'acueducto', 'aseguramiento_salud', 'ipm']]
icfes_selected = icfes[['PUNT_MATEMATICAS', 'PUNT_INGLES', 'PUNT_SOCIALES_CIUDADANAS', 'PUNT_C_NATURALES', 'PUNT_GLOBAL']]

# Asegurarte de que ambos datasets tienen el mismo número de filas
# Aquí asumimos que están alineados por el índice
# Si no es así, puedes usar un método como merge o join con una clave adecuada
combined_data = pd.concat([hogares_selected.reset_index(drop=True), icfes_selected.reset_index(drop=True)], axis=1).dropna()

# Estandarizar los datos
scaler = StandardScaler()
scaled_data = scaler.fit_transform(combined_data)

# Definir el modelo K-means con 3 clústeres
kmeans = KMeans(n_clusters=3, random_state=0)

# Entrenar el modelo con los datos estandarizados
kmeans.fit(scaled_data)

# Obtener los clústeres y asignarlos al DataFrame
combined_data['cluster'] = kmeans.labels_

# Mostrar los primeros registros con sus clústeres asignados
print(combined_data.head())

# Crear un gráfico de dispersión utilizando dos variables para visualizar los clústeres
plt.scatter(combined_data['PUNT_GLOBAL'], combined_data['ipm'], c=combined_data['cluster'], cmap='viridis')
plt.xlabel('Puntaje Global ICFES')
plt.ylabel('Índice de Pobreza Multidimensional (IPM)')
plt.title('Agrupación de Hogares según Puntaje Global y Condiciones del Hogar')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# <ipython-input-7-38b4649f2637>:7: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   hogares = pd.read_csv('hogares_total_limpios_descargado.csv')
# <ipython-input-7-38b4649f2637>:8: DtypeWarning: Columns (45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   icfes = pd.read_csv('results_icfes_total.csv', delimiter=';')
